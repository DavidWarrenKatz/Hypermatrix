# %%
import os
import pyBigWig
import numpy as np
from scipy.stats import ks_2samp
import h5py

# Import variables from config_and_print.py
from config_and_print import methy_directory, output_directory, resolutions, filtered_list

# Read the filtered bam list
with open(filtered_list, 'r') as f:
    filtered_prefixes = set(line.strip() for line in f)

# Function to process each bigWig file
def process_bigwig_file(bigwigfile, large_bin_size, small_bin_size, resolution_label, base_directory, prefix):
    bw = pyBigWig.open(bigwigfile)
    chromosomes = bw.chroms()

    for chrom in chromosomes:
        # Ensure chrom_string is always in the format 'chrN'
        if isinstance(chrom, int) or chrom.isdigit():
            chrom_string = f'chr{chrom}'
        else:
            chrom_string = chrom if chrom.startswith('chr') else f'chr{chrom}'

        if chrom_string in [f'chr{i}' for i in range(1, 23)]:
            # Create chromosome-specific directory if it doesn't exist
            chrom_directory = os.path.join(base_directory, chrom_string)
            os.makedirs(chrom_directory, exist_ok=True)

            # Define the filename for the matrix
            new_filename = os.path.join(chrom_directory, f'{prefix}_{chrom_string}.h5')

            # Check if the file already exists
            if os.path.exists(new_filename):
                print(f"File {new_filename} already exists, skipping computation.")
                continue

            chrom_length = chromosomes[chrom]
            large_bins = range(0, chrom_length, large_bin_size)
            num_large_bins = len(large_bins)

            integrals = np.zeros((large_bin_size // small_bin_size, num_large_bins))

            for i, large_bin_start in enumerate(large_bins):
                for j in range(large_bin_size // small_bin_size):
                    small_bin_start = large_bin_start + j * small_bin_size
                    small_bin_end = small_bin_start + small_bin_size

                    # Ensure that the coordinates are within the chromosome boundaries
                    if small_bin_start < 0:
                        small_bin_start = 0
                    if small_bin_end > chrom_length:
                        small_bin_end = chrom_length

                    # Check if the adjusted small_bin_start is still greater than or equal to small_bin_end
                    if small_bin_start >= small_bin_end:
                        continue

                    try:
                        # Get data within the small bin
                        small_bin_data = bw.values(chrom, int(small_bin_start), int(small_bin_end))

                        # Calculate the integral of data in the small bin
                        integral = np.trapz(small_bin_data)

                        # Store the integral in the corresponding list
                        integrals[j, i] = integral
                    except Exception as e:
                        # Print the exception and relevant information
                        print(f"An error occurred for chromosome {chrom}, large bin {i}, small bin {j}: {e}")

            # create your matrices
            num_rows, num_columns = integrals.shape
            p_value_ks_matrix = np.zeros((num_columns, num_columns))
            epsilon = 1e-10  # Define your epsilon value here

            for i in range(num_columns):
                for j in range(i, num_columns):
                    if i == j:
                        p_value_ks_matrix[i, j] = 1.0
                    else:
                        _, ks_p_value = ks_2samp(integrals[:, i], integrals[:, j])

                        p_value_ks_matrix[i, j] = np.log10(ks_p_value + epsilon)
                        p_value_ks_matrix[j, i] = np.log10(ks_p_value + epsilon)

            # take the correlation matrices of all the matrices
            correlation_ks_p_value = np.corrcoef(p_value_ks_matrix) + 1

            # Save the correlation epigenetic matrix as a .h5 file
            with h5py.File(new_filename, 'w') as hf:
                hf.create_dataset('methy_matrix', data=correlation_ks_p_value)

# Ensure resolutions is processed as a list of strings
resolutions_list = [res.strip() for res in resolutions.split(',')]

# Iterate through the files in methy_directory
for root, dirs, files in os.walk(methy_directory):
    for file in files:
        if file.endswith('.methy.b37.bw'):
            # Extract the prefix for filtering
            prefix = '.'.join(file.split('.')[:2])
            if prefix in filtered_prefixes:
                bigwigfile = os.path.join(root, file)
                print(f"Processing {bigwigfile}")
                for resolution in resolutions_list:
                    try:
                        res_value, res_label = resolution.split(":")
                        # Create the base directory for the matrices
                        base_directory = os.path.join(output_directory, f'methy_{res_label}_correlation_dir')
                        os.makedirs(base_directory, exist_ok=True)
                        large_bin_size = int(res_value)
                        small_bin_size = large_bin_size // 100
                        process_bigwig_file(bigwigfile, large_bin_size, small_bin_size, res_label, base_directory, prefix)
                    except ValueError:
                        print(f"Invalid resolution format: {resolution}")
# Out:
# Processing /home/dwk681/workspace/cluster_cells_from_GSE189158_NOMe_HiC/filesFromCluster/bam/methylation/filter_low_qual/sc24.ACTTGA.methy.b37.bw
# File ../../projects/single_cell_files/methy_1Mb_correlation_dir/chr1/sc24.ACTTGA_chr1.h5 already exists, skipping computation.
# File ../../projects/single_cell_files/methy_1Mb_correlation_dir/chr2/sc24.ACTTGA_chr2.h5 already exists, skipping computation.
# File ../../projects/single_cell_files/methy_1Mb_correlation_dir/chr3/sc24.ACTTGA_chr3.h5 already exists, skipping computation.
# File ../../projects/single_cell_files/methy_1Mb_correlation_dir/chr4/sc24.ACTTGA_chr4.h5 already exists, skipping computation.
# File ../../projects/single_cell_files/methy_1Mb_correlation_dir/chr5/sc24.ACTTGA_chr5.h5 already exists, skipping computation.
# File ../../projects/single_cell_files/methy_1Mb_correlation_dir/chr6/sc24.ACTTGA_chr6.h5 already exists, skipping computation.
# File ../../projects/single_cell_files/methy_1Mb_correlation_dir/chr7/sc24.ACTTGA_chr7.h5 already exists, skipping computation.
# File ../../projects/single_cell_files/methy_1Mb_correlation_dir/chr8/sc24.ACTTGA_chr8.h5 already exists, skipping computation.
# File ../../projects/single_cell_files/methy_1Mb_correlation_dir/chr9/sc24.ACTTGA_chr9.h5 already exists, skipping computation.
# File ../../projects/single_cell_files/methy_1Mb_correlation_dir/chr10/sc24.ACTTGA_chr10.h5 already exists, skipping computation.
# File ../../projects/single_cell_files/methy_1Mb_correlation_dir/chr11/sc24.ACTTGA_chr11.h5 already exists, skipping computation.
# File ../../projects/single_cell_files/methy_1Mb_correlation_dir/chr12/sc24.ACTTGA_chr12.h5 already exists, skipping computation.
# File ../../projects/single_cell_files/methy_1Mb_correlation_dir/chr13/sc24.ACTTGA_chr13.h5 already exists, skipping computation.
# File ../../projects/single_cell_files/methy_1Mb_correlation_dir/chr14/sc24.ACTTGA_chr14.h5 already exists, skipping computation.
# File ../../projects/single_cell_files/methy_1Mb_correlation_dir/chr15/sc24.ACTTGA_chr15.h5 already exists, skipping computation.
# File ../../projects/single_cell_files/methy_1Mb_correlation_dir/chr16/sc24.ACTTGA_chr16.h5 already exists, skipping computation.
# File ../../projects/single_cell_files/methy_1Mb_correlation_dir/chr17/sc24.ACTTGA_chr17.h5 already exists, skipping computation.
# File ../../projects/single_cell_files/methy_1Mb_correlation_dir/chr18/sc24.ACTTGA_chr18.h5 already exists, skipping computation.
# File ../../projects/single_cell_files/methy_1Mb_correlation_dir/chr19/sc24.ACTTGA_chr19.h5 already exists, skipping computation.
# File ../../projects/single_cell_files/methy_1Mb_correlation_dir/chr20/sc24.ACTTGA_chr20.h5 already exists, skipping computation.
# File ../../projects/single_cell_files/methy_1Mb_correlation_dir/chr21/sc24.ACTTGA_chr21.h5 already exists, skipping computation.
# File ../../projects/single_cell_files/methy_1Mb_correlation_dir/chr22/sc24.ACTTGA_chr22.h5 already exists, skipping computation.
# Processing /home/dwk681/workspace/cluster_cells_from_GSE189158_NOMe_HiC/filesFromCluster/bam/methylation/filter_low_qual/sc14.TAGCTT.methy.b37.bw
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[10], line 115
#     113     large_bin_size = int(res_value)
#     114     small_bin_size = large_bin_size // 100
# --> 115     process_bigwig_file(bigwigfile, large_bin_size, small_bin_size, res_label, base_directory, prefix)
#     116 except ValueError:
#     117     print(f"Invalid resolution format: {resolution}")
#
# Cell In[10], line 65, in process_bigwig_file(bigwigfile, large_bin_size, small_bin_size, resolution_label, base_directory, prefix)
#      62 small_bin_data = bw.values(chrom, int(small_bin_start), int(small_bin_end))
#      64 # Calculate the integral of data in the small bin
# ---> 65 integral = np.trapz(small_bin_data)
#      67 # Store the integral in the corresponding list
#      68 integrals[j, i] = integral
#
# File <__array_function__ internals>:200, in trapz(*args, **kwargs)
#
# File ~/.conda/envs/multiomics6/lib/python3.8/site-packages/numpy/lib/function_base.py:4859, in trapz(y, x, dx, axis)
#    4773 @array_function_dispatch(_trapz_dispatcher)
#    4774 def trapz(y, x=None, dx=1.0, axis=-1):
#    4775     r"""
#    4776     Integrate along the given axis using the composite trapezoidal rule.
#    4777
#    (...)
#    4857     array([2.,  8.])
#    4858     """
# -> 4859     y = asanyarray(y)
#    4860     if x is None:
#    4861         d = dx
#
# KeyboardInterrupt:

# %%
# Out:
# ['1000000', '1Mb']
